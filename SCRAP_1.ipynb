# %%
from bs4 import BeautifulSoup as bs
import requests as re

# %%
website='https://subslikescript.com/movie/Titanic-120338'

# %%
result=re.get(website)

# %%
content=result.text

# %%
print(content)
# Out:
# <!doctype html>
# <html lang="en" dir="ltr">
# <head>
# 	<!-- Global site tag (gtag.js) - Google Analytics -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
# </script>
#
# 	<meta charset="utf-8">
# 	<title>Titanic (1997) Movie Script  | Subs like Script</title>
# 	<meta name="description" content="Read Titanic Movie Script. Created from srt subtitles. ">
# 	<meta name="keywords" content="transcript, movie, subtitles, scripts, film, video, media, subs, srt ">
# 	<meta name="viewport" content="width=device-width, initial-scale=1">
# 	<meta name="robots" content="index, follow">
# 	<link rel="shortcut icon" href="/favicon.ico">
# 	<link media="all" type="text/css" rel="stylesheet" href="/styles/main.css">
#
# ...

# %%
result
# Out:
# <Response [200]>

# %%
soup = bs(content, 'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
# </script>
# <meta charset="utf-8"/>
# <title>Titanic (1997) Movie Script  | Subs like Script</title>
# <meta content="Read Titanic Movie Script. Created from srt subtitles. " name="description"/>
# <meta content="transcript, movie, subtitles, scripts, film, video, media, subs, srt " name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="index, follow" name="robots"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/styles/main.css" media="all" rel="stylesheet" type="text/css"/>
# ...

# %%
box = soup.find('article', class_='main-article')

# %%
print(box)
# Out:
# <article class="main-article">
# <h1>Titanic (1997) - full transcript</h1>
# <p class="plot">84 years later, a 100 year-old woman named Rose DeWitt Bukater tells the story to her granddaughter Lizzy Calvert, Brock Lovett, Lewis Bodine, Bobby Buell and Anatoly Mikailavich on the Keldysh about her life set in April 10th 1912, on a ship called Titanic when young Rose boards the departing ship with the upper-class passengers and her mother, Ruth DeWitt Bukater, and her fiancé, Caledon Hockley. Meanwhile, a drifter and artist named Jack Dawson and his best friend Fabrizio De Rossi win third-class tickets to the ship in a game. And she explains the whole story from departure until the death of Titanic on its first and last voyage April 15th, 1912 at 2:20 in the morning.</p>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- subslikescript horizontal links top -->
# ...

# %%
title = box.find('h1').get_text()

# %%
print(title)
# Out:
# Titanic (1997) - full transcript

# %%
transcript = box.find('div', class_='full-script').get_text(strip=True, separator=' ')

# %%
print(transcript)
# Out:
# 13 meters. You should see it. Okay, take her up and over the bow rail. Mir 2, we're going over the bow.
# Stay with us. Okay, quiet. We're rolling. Seeing her coming out of the
# darkness like a ghost ship... ...still gets me every time. To see the sad ruin of the
# great ship sitting here... ...where she landed at
# 2:30 in the morning Of April 15, 1912 ...after her long fall... ...from the world above. You are so full of shit, boss. Dive 6. Here we are again
# on the deck of Titanic. 2% miles down
# 3,821 meters- The pressure outside is 3% tons per square inch These windows are
# 9 inches thick. If they go, it's sayonara in two microseconds. All right, enough of that bullshit. Just put her down on the roof of
# the officers' quarters like yesterday. Mir 2, we're landing right over the
# Grand Staircase. You guys set to launch? Yeah, Brock. Launching Dunkin now.
# Go, Charlie. - All right, tether out.
# - Tether out. Okay, Brock, we're dropping
# ...

# %%
website='https://subslikescript.com/'

# %%
result_1=re.get(website)

# %%
content_1=result.text

# %%
print(content_1)
# Out:
# <!doctype html>
# <html lang="en" dir="ltr">
# <head>
# 	<!-- Global site tag (gtag.js) - Google Analytics -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
# </script>
#
# 	<meta charset="utf-8">
# 	<title>Titanic (1997) Movie Script  | Subs like Script</title>
# 	<meta name="description" content="Read Titanic Movie Script. Created from srt subtitles. ">
# 	<meta name="keywords" content="transcript, movie, subtitles, scripts, film, video, media, subs, srt ">
# 	<meta name="viewport" content="width=device-width, initial-scale=1">
# 	<meta name="robots" content="index, follow">
# 	<link rel="shortcut icon" href="/favicon.ico">
# 	<link media="all" type="text/css" rel="stylesheet" href="/styles/main.css">
#
# ...

# %%
soup_1=bs(content_1,'lxml')

# %%
box_1=soup_1.find('ul',class_="scripts-list")

# %%
box_2 = soup_1.find('article', class_='main-article')
# Out:
# None

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
# </script>
# <meta charset="utf-8"/>
# <title>Titanic (1997) Movie Script  | Subs like Script</title>
# <meta content="Read Titanic Movie Script. Created from srt subtitles. " name="description"/>
# <meta content="transcript, movie, subtitles, scripts, film, video, media, subs, srt " name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="index, follow" name="robots"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/styles/main.css" media="all" rel="stylesheet" type="text/css"/>
# ...

# %%
print(soup_1)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
# </script>
# <meta charset="utf-8"/>
# <title>Titanic (1997) Movie Script  | Subs like Script</title>
# <meta content="Read Titanic Movie Script. Created from srt subtitles. " name="description"/>
# <meta content="transcript, movie, subtitles, scripts, film, video, media, subs, srt " name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="index, follow" name="robots"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/styles/main.css" media="all" rel="stylesheet" type="text/css"/>
# ...

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
# </script>
# <meta charset="utf-8"/>
# <title>Titanic (1997) Movie Script  | Subs like Script</title>
# <meta content="Read Titanic Movie Script. Created from srt subtitles. " name="description"/>
# <meta content="transcript, movie, subtitles, scripts, film, video, media, subs, srt " name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="index, follow" name="robots"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/styles/main.css" media="all" rel="stylesheet" type="text/css"/>
# ...

# %%
website_1='https://subslikescript.com/'

# %%
result_2=re.get(website_1)

# %%
content_2=result_2.text

# %%
box_3=bs(content_2,'lxml')

# %%
print(box_3)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
# </script>
# <meta charset="utf-8"/>
# <title>Subs like Script - read transcript of any movie or tv show  | Subs like Script</title>
# <meta content="Transcripts of media are based on its subtitles. Huge database of movies' and series' english scripts " name="description"/>
# <meta content="transcript, transcription, subtitles, subs, scripts, srt, screenplay, tv show, movies, series, episode, season, film, cartoon, comics, television, read online, dialogues, springfieldspringfield, springfield " name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# ...

# %%
boco=box_3.text

# %%
print(boco)
# Out:
# Subs like Script - read transcript of any movie or tv show  | Subs like Script
#
#
#
#
#
#
#
#
#
#
#
#
#
# SUBSLIKESCRIPT
#
#
#
# Movies
# TV Shows
#
#
#
#
# Subtitles like scripts. What's here?
# Here you can find any scripts for Movies and Tv Shows / Tv Series. Try searching for your favorite:
#
#
#
# Search
#
# Or just check out full lists:
# Movies Tv Shows / Series
#
#
#
#
#
# Last added Movies' transcripts:
#
# Makeup
# Lean Sheat Nosaat
# Phases of the Moon
# Detective Song Ci
# 90210 Shark Attack
# Hosto
# Genocidal Organ
# Malibu Shark Attack
# Silent Parade
# Café Nagler
#
#
#
#
#
#
#
# Last added Tv Shows' scripts:
#
# Black Sheep Squadron - season 2, episode 6 - Ten'll Get You Five
# Ultraman New Generation Stars - season 1, episode 1 - Episode #1.1
# Kingdoms - season 1, episode 3 - Episode #1.3
# Kingdoms - season 1, episode 1 - Episode #1.1
# The Great Eagle - season 1, episode 3 - Episode #1.3
# The Great Eagle - season 1, episode 2 - Episode #1.2
# ...

# %%
boueco=box_3.find('main',class_="mainpage")

# %%
print(boueco)
# Out:
# <main class="mainpage">
# <h1>Subtitles like scripts. What's here?</h1>
# <p>Here you can find any scripts for Movies and Tv Shows / Tv Series. Try searching for your favorite:</p>
# <nav>
# <form action="/search" class="searchzone" method="get" name="search">
# <input class="searchbox" name="q" type="text"/>
# <button class="searchbutton">Search</button>
# </form>
# </nav><p>Or just check out full lists:</p>
# <nav class="listslinksbox"><a href="/movies" title="Full list of movies' scripts">Movies</a> <a href="/series" title="Full list of series' scripts">Tv Shows / Series</a></nav>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- subslikescript horizontal links top -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-6250492176235895" data-ad-format="link" data-ad-slot="3068516580" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# ...

# %%
print(boueco.text)
# Out:
# Subtitles like scripts. What's here?
# Here you can find any scripts for Movies and Tv Shows / Tv Series. Try searching for your favorite:
#
#
#
# Search
#
# Or just check out full lists:
# Movies Tv Shows / Series
#
#
#
#
#
# Last added Movies' transcripts:
#
# Makeup
# Lean Sheat Nosaat
# Phases of the Moon
# Detective Song Ci
# 90210 Shark Attack
# Hosto
# Genocidal Organ
# Malibu Shark Attack
# Silent Parade
# Café Nagler
#
#
#
#
#
#
#
# Last added Tv Shows' scripts:
#
# Black Sheep Squadron - season 2, episode 6 - Ten'll Get You Five
# Ultraman New Generation Stars - season 1, episode 1 - Episode #1.1
# Kingdoms - season 1, episode 3 - Episode #1.3
# Kingdoms - season 1, episode 1 - Episode #1.1
# The Great Eagle - season 1, episode 3 - Episode #1.3
# The Great Eagle - season 1, episode 2 - Episode #1.2
# The Great Eagle - season 1, episode 1 - Episode #1.1
# Suspect - season 1, episode 5 - Episode #1.5
# American Horror Story - season 10, episode 8 - Inside
# ...

# %%
len(boueco)
# Out:
# 34

# %%
boe=boueco.find('article')

# %%
print(boe)
# Out:
# <article>
# <h2>Last added Movies' transcripts: </h2>
# <ul class="scripts-list">
# <a href="movie/Makeup-13460584" title="Makeup Movie - read transcript"><li>Makeup</li></a>
# <a href="movie/Lean_Sheat_Nosaat-2123223" title="Lean Sheat Nosaat Movie - read transcript"><li>Lean Sheat Nosaat</li></a>
# <a href="movie/Phases_of_the_Moon-21652624" title="Phases of the Moon Movie - read transcript"><li>Phases of the Moon</li></a>
# <a href="movie/Detective_Song_Ci-24825344" title="Detective Song Ci Movie - read transcript"><li>Detective Song Ci</li></a>
# <a href="movie/90210_Shark_Attack-3544654" title="90210 Shark Attack Movie - read transcript"><li>90210 Shark Attack</li></a>
# <a href="movie/Hosto-27912053" title="Hosto Movie - read transcript"><li>Hosto</li></a>
# <a href="movie/Genocidal_Organ-3615160" title="Genocidal Organ Movie - read transcript"><li>Genocidal Organ</li></a>
# ...

# %%
boe_2=boe.find_all('li')

# %%
for i in boe_2:
    print(i.getText())
# Out:
# Makeup
# Lean Sheat Nosaat
# Phases of the Moon
# Detective Song Ci
# 90210 Shark Attack
# Hosto
# Genocidal Organ
# Malibu Shark Attack
# Silent Parade
# Café Nagler

# %%
bour_1=boueco.find_all('article')

# %%
len(bour_1)
# Out:
# 4

# %%
name=[]
for i in bour_1:
    for j in i.find_all('li'):
        print(j.getText())
        name.append(j.getText())
# Out:
# Makeup
# Lean Sheat Nosaat
# Phases of the Moon
# Detective Song Ci
# 90210 Shark Attack
# Hosto
# Genocidal Organ
# Malibu Shark Attack
# Silent Parade
# Café Nagler
# Black Sheep Squadron - season 2, episode 6 - Ten'll Get You Five
# Ultraman New Generation Stars - season 1, episode 1 - Episode #1.1
# Kingdoms - season 1, episode 3 - Episode #1.3
# Kingdoms - season 1, episode 1 - Episode #1.1
# The Great Eagle - season 1, episode 3 - Episode #1.3
# The Great Eagle - season 1, episode 2 - Episode #1.2
# The Great Eagle - season 1, episode 1 - Episode #1.1
# Suspect - season 1, episode 5 - Episode #1.5
# American Horror Story - season 10, episode 8 - Inside
# Man in a Suitcase - season 1, episode 3 - Day of Execution
# BROS. Last Call - 10
# Rubaru Roshni - 10
# Banking on Africa: The Bitcoin Revolution - 10
# Breaking the Chain - 10
# Ludo - 10
# Papachenko - 10
# Couch Connections - 9.9
# Garroter - 9.9
# Hot Money - 9.9
# Transformer - 9.8
# Kid Cosmic - 10
# Bluey - 9.7
# ...

# %%
for i in name:
    print(j.getText())
# Out:
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5
# Paranormal - 9.5

# %%
print(name)
# Out:
# ['Makeup', 'Lean Sheat Nosaat', 'Phases of the Moon', 'Detective Song Ci', '90210 Shark Attack', 'Hosto', 'Genocidal Organ', 'Malibu Shark Attack', 'Silent Parade', 'Café Nagler', "Black Sheep Squadron - season 2, episode 6 - Ten'll Get You Five", 'Ultraman New Generation Stars - season 1, episode 1 - Episode #1.1', 'Kingdoms - season 1, episode 3 - Episode #1.3', 'Kingdoms - season 1, episode 1 - Episode #1.1', 'The Great Eagle - season 1, episode 3 - Episode #1.3', 'The Great Eagle - season 1, episode 2 - Episode #1.2', 'The Great Eagle - season 1, episode 1 - Episode #1.1', 'Suspect - season 1, episode 5 - Episode #1.5', 'American Horror Story - season 10, episode 8 - Inside', 'Man in a Suitcase - season 1, episode 3 - Day of Execution', 'BROS. Last Call - 10', 'Rubaru Roshni - 10', 'Banking on Africa: The Bitcoin Revolution - 10', 'Breaking the Chain - 10', 'Ludo - 10', 'Papachenko - 10', 'Couch Connections - 9.9', 'Garroter - 9.9', 'Hot Money - 9.9', 'Transformer - 9.8', 'Kid Co
# ...

# %%
len(name)
# Out:
# 40
